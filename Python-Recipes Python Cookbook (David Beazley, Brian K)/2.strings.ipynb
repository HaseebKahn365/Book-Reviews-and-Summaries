# %%
import re as reg


line = 'asdf fjdk; afed, fjek,asdf, foo'

filt = reg.split(r'[;,\s]', line)
filt = [ x for x in filt if len(x)>0]
filt
# Out:
# ['asdf', 'fjdk', 'afed', 'fjek', 'asdf', 'foo']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import re

text = """
John: +1-555-1234, johndoe@gmail.com
Jane: +44-20-7890-1234, jane@work.co.uk
haseeb_khan@gmail.com
Sales: sales@company.com
"""

first_email = re.search(r'[\w.-]+@[\w.-]+\.\w+', text)
print(first_email)
# Out:
# <re.Match object; span=(20, 37), match='johndoe@gmail.com'>

# %%
t = re.findall(r'\+\d+[\d-]+', text)
t
# Out:
# ['+1-555-1234', '+44-20-7890-1234']

# %%
re.split("\n+", text)
# Out:
# ['',
#  'John: +1-555-1234, johndoe@gmail.com',
#  'Jane: +44-20-7890-1234, jane@work.co.uk',
#  'haseeb_khan@gmail.com',
#  'Sales: sales@company.com',
#  '']

# %%
anon = re.sub(r'[\w.-]+@[\w.-]+', '**Email**', text)
anon
# Out:
# '\nJohn: +1-555-1234, **Email**\nJane: +44-20-7890-1234, **Email**\n**Email**\nSales: **Email**\n'

# %%
print("\n=== 5. finditer ===")
for match in re.finditer(r'(\w+): ([\w@.-]+)', text):
    print(f"Key: {match.group(1):10} Value: {match.group(2)}")
# Out:
# === 5. finditer ===
# Key: Sales      Value: sales@company.com

# %%
import os
fs = os.listdir('.')
print([x for x in fs if x.endswith('.ipynb')])
# Out:
# ['1.data_structures.ipynb', '2.strings.ipynb']

# %%
print(text)
text.find("@")
# Out:
# John: +1-555-1234, johndoe@gmail.com
# Jane: +44-20-7890-1234, jane@work.co.uk
# haseeb_khan@gmail.com
# Sales: sales@company.com
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 2
#       1 print(text)
# ----> 2 text.findall("@")
#
# AttributeError: 'str' object has no attribute 'findall'

# %%
datepat = re.compile(r'(\d+)/(\d+)/(\d+)')

# %%
import re
datepat = re.compile(r'\d+/\d+/\d+')
text = 'Today is 11/27/2012. PyCon starts 3/13/2013.'
g = datepat.match("11/27/20")
g.group(0)
# Out:
# '11/27/20'

# %%
em = ""

# %%
import unicodedata
s1 = 'Spicy Jalape\u00f1o'
s2 = 'Spicy Jalapen\u0303o'
t1 = unicodedata.normalize('NFC', s1)
t2 = unicodedata.normalize('NFC', s2)
t1 == t2
print(ascii(t1))
'Spicy Jalape\xf1o'
# Out:
# 'Spicy Jalape\xf1o'
# 'Spicy Jalapeño'

# %%
t = """
     -----hello====="""
t.strip(\' -===')
# Out:
# 'hello'

# %%
str = "{has} is man".format(has = "Haseeb")
print(str)
